# %% [markdown]
# # Exercise 1
#
# Using pandas
#
# * Read the csv "Glasgow_Weather.csv"
# * Create a variable that is a filter where tempMin is greater than or equal to 0
# * Create a variable that is a filter where tempMax is less than or equal to 5
# * Create a variable that is a filter where desc does not equal rain
# * Using logical operation AND together these filters into another variable and name it mask
# * Use the variable mask on the dataframe and show the results
# * Assign the df with the mask to a new variable called filtered_df

# %%
# ENTER YOUR CODE HERE
import pandas as pd

df = pd.read_csv("Glasgow_Weather.csv",index_col="day")
df.dropna(inplace=True)

filter_tempMin = df["tempMin"] >= 0
filter_tempMax = df["tempMax"] <= 5
filter_desc = df["desc"] != "rain"
mask = filter_tempMax & filter_tempMin & filter_desc

df[mask]
# Out:
#             tempMin  tempMax  \
# day
# 2015-01-16     0.68     4.11
# 2015-01-31     1.55     4.61
# 2015-03-02     0.99     4.37
# 2016-01-19     1.06     3.80
# 2016-01-20     1.38     3.59
# 2016-02-13     0.74     3.42
# 2016-11-18     0.17     4.73
# 2017-01-22     0.26     3.22
# 2017-02-09     0.29     4.04
# 2017-02-12     2.38     4.13
# 2017-11-25     0.42     4.30
# 2017-11-29     0.09     4.87
# 2017-11-30     0.14     4.47
# 2017-12-08     0.14     2.51
# 2018-01-05     2.31     4.21
# 2018-01-09     0.31     3.64
# 2018-01-10     1.72     4.51
# 2018-01-11     0.11     3.95
# 2018-03-03     0.12     1.81
# 2019-01-03     0.08     4.16
#
#                                                       summary  \
# day
# 2015-01-16                            Foggy in the afternoon.
# 2015-01-31                          Clear throughout the day.
# 2015-03-02                  Mostly cloudy throughout the day.
# 2016-01-19                Foggy in the morning and overnight.
# 2016-01-20                              Foggy in the morning.
# 2016-02-13                  Mostly cloudy throughout the day.
# 2016-11-18                  Partly cloudy throughout the day.
# 2017-01-22                Foggy in the morning and overnight.
# 2017-02-09                  Mostly cloudy throughout the day.
# 2017-02-12                       Overcast throughout the day.
# 2017-11-25                  Partly cloudy throughout the day.
# 2017-11-29                          Clear throughout the day.
# 2017-11-30                          Clear throughout the day.
# 2017-12-08                          Clear throughout the day.
# 2018-01-05                  Mostly cloudy throughout the day.
# 2018-01-09                                   Foggy overnight.
# 2018-01-10                Foggy in the morning and overnight.
# 2018-01-11  Foggy until morning, starting again in the eve...
# 2018-03-03                       Overcast throughout the day.
# 2019-01-03                       Overcast throughout the day.
#
#                          desc  cloudCover  humidity  windSpeed  visibility
# day
# 2015-01-16  partly-cloudy-day        0.52      0.82       9.64        5.79
# 2015-01-31          clear-day        0.28      0.74       9.99        6.22
# 2015-03-02  partly-cloudy-day        0.68      0.85      11.08        6.16
# 2016-01-19  partly-cloudy-day        0.87      0.95       1.07        3.43
# 2016-01-20  partly-cloudy-day        0.77      0.94       2.03        2.77
# 2016-02-13  partly-cloudy-day        0.56      0.87       6.52        6.06
# 2016-11-18  partly-cloudy-day        0.52      0.92       2.30        5.30
# 2017-01-22  partly-cloudy-day        0.76      0.93       1.25        3.27
# 2017-02-09  partly-cloudy-day        0.48      0.79       4.51        6.22
# 2017-02-12  partly-cloudy-day        0.87      0.78      10.40        6.22
# 2017-11-25  partly-cloudy-day        0.40      0.88       7.17        6.21
# 2017-11-29          clear-day        0.14      0.76       4.43        6.22
# 2017-11-30          clear-day        0.20      0.76       4.98        6.22
# 2017-12-08          clear-day        0.14      0.75      10.62        6.22
# 2018-01-05  partly-cloudy-day        0.82      0.93       3.19        5.62
# 2018-01-09  partly-cloudy-day        0.80      0.86       5.07        6.08
# 2018-01-10             cloudy        0.95      0.93       2.53        3.35
# 2018-01-11                fog        0.88      0.93       1.14        1.99
# 2018-03-03             cloudy        0.89      0.77       8.73        6.13
# 2019-01-03             cloudy        0.95      0.90       1.90        6.28

# %%
df_filter = df[mask]

# %% [markdown]
# # Exercise 2
#
# * Create another variable called df_inverse_filter where you filter on the inverse on the above mask
# * Output the data of df_inverse_filter

# %%
# ENTER YOUR CODE HERE
df_inverse_filter = df[~mask]
df_inverse_filter
# Out:
#             tempMin  tempMax                                  summary  \
# day
# 2015-01-01     7.53    12.23       Possible light rain until evening.
# 2015-01-02     3.58     7.15  Possible light rain throughout the day.
# 2015-01-03    -0.61     6.54                Clear throughout the day.
# 2015-01-04    -0.63     7.59        Mostly cloudy throughout the day.
# 2015-01-05     6.51    10.43             Overcast throughout the day.
# ...             ...      ...                                      ...
# 2019-11-26     8.55    10.57        Mostly cloudy throughout the day.
# 2019-11-27     5.79     9.40        Mostly cloudy throughout the day.
# 2019-11-28     2.30     6.67        Mostly cloudy throughout the day.
# 2019-11-29     1.08     6.14        Mostly cloudy throughout the day.
# 2019-11-30     0.42     5.69        Mostly cloudy throughout the day.
#
#                          desc  cloudCover  humidity  windSpeed  visibility
# day
# 2015-01-01               rain        0.80      0.89      14.69        4.43
# 2015-01-02               rain        0.62      0.79      15.04        5.64
# 2015-01-03               rain        0.31      0.84       4.48        6.20
# 2015-01-04  partly-cloudy-day        0.78      0.85       4.35        6.22
# 2015-01-05  partly-cloudy-day        0.85      0.91       6.20        5.91
# ...                       ...         ...       ...        ...         ...
# 2019-11-26               rain        0.96      0.85       6.80       10.00
# 2019-11-27               rain        0.87      0.85       6.82        9.03
# 2019-11-28  partly-cloudy-day        0.40      0.79       5.15       10.00
# 2019-11-29          clear-day        0.18      0.76       4.85        9.11
# 2019-11-30  partly-cloudy-day        0.55      0.72       4.79       10.00
#
# [1591 rows x 8 columns]

# %% [markdown]
# # Exercise 3
#
# Using df_filter
#
# * Sort the column tempMin in ascending order
# * Sort the column desc in descending order
# * Sort both columns tempMax and summary in ascending order
# * Sort both columns cloudCover and humidity but cloudCover in ascending order and humidity in descending order.

# %%
# ENTER YOUR CODE HERE
df_filter.sort_values("tempMin")
df_filter.sort_values("desc", ascending=False)
df_filter.sort_values(by=["tempMax", "summary"])
df_filter.sort_values(by=["cloudCover", "humidity"],ascending=[True,False])
# Out:
#             tempMin  tempMax  \
# day
# 2017-11-29     0.09     4.87
# 2017-12-08     0.14     2.51
# 2017-11-30     0.14     4.47
# 2015-01-31     1.55     4.61
# 2017-11-25     0.42     4.30
# 2017-02-09     0.29     4.04
# 2016-11-18     0.17     4.73
# 2015-01-16     0.68     4.11
# 2016-02-13     0.74     3.42
# 2015-03-02     0.99     4.37
# 2017-01-22     0.26     3.22
# 2016-01-20     1.38     3.59
# 2018-01-09     0.31     3.64
# 2018-01-05     2.31     4.21
# 2016-01-19     1.06     3.80
# 2017-02-12     2.38     4.13
# 2018-01-11     0.11     3.95
# 2018-03-03     0.12     1.81
# 2018-01-10     1.72     4.51
# 2019-01-03     0.08     4.16
#
#                                                       summary  \
# day
# 2017-11-29                          Clear throughout the day.
# 2017-12-08                          Clear throughout the day.
# 2017-11-30                          Clear throughout the day.
# 2015-01-31                          Clear throughout the day.
# 2017-11-25                  Partly cloudy throughout the day.
# 2017-02-09                  Mostly cloudy throughout the day.
# 2016-11-18                  Partly cloudy throughout the day.
# 2015-01-16                            Foggy in the afternoon.
# 2016-02-13                  Mostly cloudy throughout the day.
# 2015-03-02                  Mostly cloudy throughout the day.
# 2017-01-22                Foggy in the morning and overnight.
# 2016-01-20                              Foggy in the morning.
# 2018-01-09                                   Foggy overnight.
# 2018-01-05                  Mostly cloudy throughout the day.
# 2016-01-19                Foggy in the morning and overnight.
# 2017-02-12                       Overcast throughout the day.
# 2018-01-11  Foggy until morning, starting again in the eve...
# 2018-03-03                       Overcast throughout the day.
# 2018-01-10                Foggy in the morning and overnight.
# 2019-01-03                       Overcast throughout the day.
#
#                          desc  cloudCover  humidity  windSpeed  visibility
# day
# 2017-11-29          clear-day        0.14      0.76       4.43        6.22
# 2017-12-08          clear-day        0.14      0.75      10.62        6.22
# 2017-11-30          clear-day        0.20      0.76       4.98        6.22
# 2015-01-31          clear-day        0.28      0.74       9.99        6.22
# 2017-11-25  partly-cloudy-day        0.40      0.88       7.17        6.21
# 2017-02-09  partly-cloudy-day        0.48      0.79       4.51        6.22
# 2016-11-18  partly-cloudy-day        0.52      0.92       2.30        5.30
# 2015-01-16  partly-cloudy-day        0.52      0.82       9.64        5.79
# 2016-02-13  partly-cloudy-day        0.56      0.87       6.52        6.06
# 2015-03-02  partly-cloudy-day        0.68      0.85      11.08        6.16
# 2017-01-22  partly-cloudy-day        0.76      0.93       1.25        3.27
# 2016-01-20  partly-cloudy-day        0.77      0.94       2.03        2.77
# 2018-01-09  partly-cloudy-day        0.80      0.86       5.07        6.08
# 2018-01-05  partly-cloudy-day        0.82      0.93       3.19        5.62
# 2016-01-19  partly-cloudy-day        0.87      0.95       1.07        3.43
# 2017-02-12  partly-cloudy-day        0.87      0.78      10.40        6.22
# 2018-01-11                fog        0.88      0.93       1.14        1.99
# 2018-03-03             cloudy        0.89      0.77       8.73        6.13
# 2018-01-10             cloudy        0.95      0.93       2.53        3.35
# 2019-01-03             cloudy        0.95      0.90       1.90        6.28

# %% [markdown]
# # Exercise 4
#
# Using df_inverse_filter
#
# * Show how to sort the index in descending order
# * Show the 5 largest values of windSpeed
# * Show the 5 smallest values of visibility

# %%
# ENTER YOUR CODE HERE

df_inverse_filter.sort_index(ascending=False)
df_inverse_filter.nlargest(5, "windSpeed")
df_inverse_filter.nsmallest(5, "visibility")
# Out:
#             tempMin  tempMax                                         summary  \
# day
# 2019-01-06     4.84     9.79  Possible light rain starting in the afternoon.
# 2018-12-25    -2.24     9.43                            Foggy until evening.
# 2015-11-03     3.98    11.38                       Foggy throughout the day.
# 2017-12-21     3.86     6.94                       Foggy throughout the day.
# 2019-01-24    -3.51     3.93           Drizzle in the evening and overnight.
#
#             desc  cloudCover  humidity  windSpeed  visibility
# day
# 2019-01-06  rain        0.97      0.99       2.55        0.19
# 2018-12-25  rain        0.92      1.00       1.84        1.23
# 2015-11-03   fog        0.87      0.92       1.50        1.39
# 2017-12-21   fog        0.78      0.93       1.52        1.50
# 2019-01-24  rain        0.81      0.99       2.23        1.52
