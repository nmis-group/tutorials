# %% [markdown]
# # Exercise 1
#
# Using Pandas
#
# * Read the Glasgow_Weather.csv and assign the index to the day column
# * Create a new column in the dataframe and call it diff which is the difference between the tempMax and tempMin
# * Remove the column visibility.

# %%
# ENTER YOUR CODE HERE
# Out:
#             tempMin  tempMax                                  summary  \
# day
# 2015-01-01     7.53    12.23       Possible light rain until evening.
# 2015-01-02     3.58     7.15  Possible light rain throughout the day.
# 2015-01-03    -0.61     6.54                Clear throughout the day.
# 2015-01-04    -0.63     7.59        Mostly cloudy throughout the day.
# 2015-01-05     6.51    10.43             Overcast throughout the day.
# ...             ...      ...                                      ...
# 2019-11-26     8.55    10.57        Mostly cloudy throughout the day.
# 2019-11-27     5.79     9.40        Mostly cloudy throughout the day.
# 2019-11-28     2.30     6.67        Mostly cloudy throughout the day.
# 2019-11-29     1.08     6.14        Mostly cloudy throughout the day.
# 2019-11-30     0.42     5.69        Mostly cloudy throughout the day.
#
#                          desc  cloudCover  humidity  windSpeed  diff
# day
# ...

# %% [markdown]
# # Exercise 2
#
# * Create a groupby object on the column summary and assign it to a variable.
# * Filter the group on "Clear throughout the day.".
# * Use value counts to find all information on desc column on the above grouping of "Clear throughout the day.".
# * Find the percetage of the value count above.

# %%
# ENTER YOUR CODE HERE
# Out:
# clear-day            0.849711
# partly-cloudy-day    0.138728
# rain                 0.011561
# Name: desc, dtype: float64

# %% [markdown]
# # Exercise 3
#
# * Use the agg method on the groupby object created in Exercise 1, showing the min, max and median for each column of the summary grouping.

# %%
# ENTER YOUR CODE HERE
# Out:
#                                                    tempMin                \
#                                                        min    max median
# summary
# Clear throughout the day.                            -7.44  14.61   3.07
# Dangerously windy in the morning and afternoon.      10.45  10.45  10.45
# Dangerously windy in the morning.                    12.53  12.53  12.53
# Dangerously windy starting in the afternoon.          9.80   9.80   9.80
# Dangerously windy until morning, starting again...   12.58  12.58  12.58
# ...                                                    ...    ...    ...
# Windy in the evening.                                 7.58  10.56   9.07
# Windy in the morning and afternoon.                   7.00   8.62   7.81
# Windy in the morning.                                10.51  11.61  11.06
# Windy overnight.                                      5.33   5.81   5.57
# Windy starting in the afternoon.                      1.57   1.57   1.57
#
# ...
