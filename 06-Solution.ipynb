# %% [markdown]
# # Exercise 1
#
# Using pandas
#
# * read the csv "avocad.csv"
# * output the dataframe
# * output the shape of the dataframe
# * output the describe function
# * output the correlation function

# %%
# ENTER YOUR CODE HERE
import pandas as pd

df = pd.read_csv("avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %% [markdown]
# # Exercise 2
#
# * Set the index to Date

# %%
# ENTER YOUR CODE HERE
df.set_index("Date", inplace=True)
df
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
# ...                ...           ...           ...      ...        ...
# 2018-02-04           7          1.63      17074.83  2046.96    1529.20
# 2018-01-28           8          1.71      13888.04  1191.70    3431.50
# 2018-01-21           9          1.87      13766.76  1191.92    2452.79
# 2018-01-14          10          1.93      16205.22  1527.63    2981.04
# 2018-01-07          11          1.62      17489.58  2894.77    2356.13
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# ...

# %% [markdown]
# # Exercise 3
#
# Using both iloc and loc on each bullet point
#
# * Filter the column average price
# * Filter the columns between Average Price and total bags
# * Filter the first row
# * Filter the first row to tenth row
# * Filter the columns between small bags and XLarge bags and the rows 11 to 40

# %%
# ENTER YOUR CODE HERE

df["AveragePrice"]

df.iloc[:,1] 
df.iloc[:,0:7]
df.iloc[0]
df.iloc[0:11]
df.iloc[11:41,7:10]

df.loc[:,"AveragePrice"]
df.loc[:,"AveragePrice":"Total Bags"]


# Issues using loc because the dates are not unique. This is a lesson in checking your dataset before working on it.
# 
# df.loc["2015-12-27"] 
# df.loc["2015-12-27":"2018-01-14"]
# Out:
#             AveragePrice  Total Volume     4046       4225    4770  Total Bags
# Date
# 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 2015-12-20          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2015-12-13          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 2015-11-29          1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...                  ...           ...      ...        ...     ...         ...
# 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
# ...

# %% [markdown]
# # Exercise 4
#
# * Reset the index

# %%
# ENTER YOUR CODE HERE
df.reset_index(inplace=True)
